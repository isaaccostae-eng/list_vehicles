# %%
# %pip install "nbformat>=4.2.0"

import pandas as pd
import plotly.express as px

car_data = pd.read_csv("../vehicles.csv")  # arquivo está na pasta list_vehicles
fig = px.histogram(car_data, x="odometer") # criar um histograma
fig.show()
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# ...
#
#    ---------------------------------------- 0/2 [fastjsonschema]
#    ---------------------------------------- 0/2 [fastjsonschema]
#    ---------------------------------------- 0/2 [fastjsonschema]
#    ---------------------------------------- 0/2 [fastjsonschema]
#    ---------------------------------------- 0/2 [fastjsonschema]
#    -------------------- ------------------- 1/2 [nbformat]
#    -------------------- ------------------- 1/2 [nbformat]
#    -------------------- ------------------- 1/2 [nbformat]
#    -------------------- ------------------- 1/2 [nbformat]
#    -------------------- ------------------- 1/2 [nbformat]
#    -------------------- ------------------- 1/2 [nbformat]
#    -------------------- ------------------- 1/2 [nbformat]
#    -------------------- ------------------- 1/2 [nbformat]
#    -------------------- ------------------- 1/2 [nbformat]
# ...
